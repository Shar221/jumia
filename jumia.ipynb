# %%
print("Hello,World")
# Out:
# Hello,World

# %%
import requests

url = "https://www.jumia.co.ke/flash-sales/"
response = requests.get(url)

print("Status:", response.status_code)
print("Length of response:", len(response.text))

# Quick check for products
if "prd" in response.text or "Flash Sales" in response.text:
    print("Some product placeholders found")
else:
    print("No product data, page likely loaded by JavaScript")
# Out:
# Status: 200
# Length of response: 494809
# Some product placeholders found

# %%
import requests
from bs4 import BeautifulSoup

response = requests.get("https://www.jumia.co.ke/flash-sales/")
soup = BeautifulSoup(response.text, "html.parser")


soup = BeautifulSoup(driver.page_source, "html.parser")
products = soup.select(".prd")


for product in products:
    
    name = product.select_one(".name")
    name = name.get_text(strip=True) if name else "N/A"

    old_price = product.select_one(".old")
    old_price = old_price.get_text(strip=True) if old_price else "N/A"

    new_price = product.select_one(".prc")
    new_price = new_price.get_text(strip=True) if new_price else "N/A"

    discount = product.select_one(".bdg._dsct")
    discount = discount.get_text(strip=True) if discount else "No discount"

    rating = product.select_one(".stars")
    rating = rating.get_text(strip=True) if rating else "N/A"

    rating_count = product.select_one(".rev")
    rating_count = rating_count.get_text(strip=True) if rating_count else "N/A"

    stock = product.select_one(".stk, .-low-stock, .-progress")
    stock = stock.get_text(strip=True) if stock else "N/A"

    link = product.select_one("a.core")
    url = "https://www.jumia.co.ke" + link["href"] if link else "N/A"

   
    print(f"Product: {name}")
    print(f"Old Price: {old_price}")
    print(f"New Price: {new_price}")
    print(f"Discount: {discount}")
    print(f"Rating: {rating}")
    print(f"Number of Ratings: {rating_count}")
    print(f"Stock Level: {stock}")
    print(f"URL: {url}")
    print("------------------------------------------------------------")

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/software-dev/python-projects/jumia/.venv/lib/python3.13/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File ~/software-dev/python-projects/jumia/.venv/lib/python3.13/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...
